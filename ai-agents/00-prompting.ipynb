# %% [markdown]
# # Building a Basic Chatbot with LangGraph
#
# In this notebook, we will build a basic chatbot (local LLM calls only) using `LangGraph`, so you can get familiar with the APIs and its structure.

# %% [markdown]
# ## Install dependencies

# %%
model_name = 'Llama-3.2-3B-Instruct.Q6_K.llamafile'

# %%
# !wget https://huggingface.co/mozilla-ai/Llama-3.2-3B-Instruct-llamafile/resolve/main/${model_name} -O ${model_name}
# !chmod +x ${model_name}

# %%
wget -O cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
chmod +x cloudflared
sudo mv cloudflared /usr/local/bin/

# %%
# !cloudflared tunnel --url http://localhost:5000 &

# %% [markdown]
# ----------
# Copyright (C) 2025 Advanced Micro Devices, Inc. All rights reserved.
#
# SPDX-License-Identifier: MIT
